# %% [markdown]
# # Prelims:
# ## Required Modules

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %matplotlib inline

# %% [markdown]
# ## Importing / Formatting Data

# %%
df = pd.read_csv("../data/train_2.csv", index_col='Page')

df.head()
# Out:
#                                                     2015-07-01  2015-07-02  \
# Page
# 2NE1_zh.wikipedia.org_all-access_spider                   18.0        11.0
# 2PM_zh.wikipedia.org_all-access_spider                    11.0        14.0
# 3C_zh.wikipedia.org_all-access_spider                      1.0         0.0
# 4minute_zh.wikipedia.org_all-access_spider                35.0        13.0
# 52_Hz_I_Love_You_zh.wikipedia.org_all-access_sp...         NaN         NaN
#
#                                                     2015-07-03  2015-07-04  \
# Page
# 2NE1_zh.wikipedia.org_all-access_spider                    5.0        13.0
# 2PM_zh.wikipedia.org_all-access_spider                    15.0        18.0
# 3C_zh.wikipedia.org_all-access_spider                      1.0         1.0
# 4minute_zh.wikipedia.org_all-access_spider                10.0        94.0
# 52_Hz_I_Love_You_zh.wikipedia.org_all-access_sp...         NaN         NaN
#
# ...

# %%
pct_change = df.pct_change(axis=1)
pct_change.head()
# Out:
#                                                     2015-07-01  2015-07-02  \
# Page
# 2NE1_zh.wikipedia.org_all-access_spider                    NaN   -0.388889
# 2PM_zh.wikipedia.org_all-access_spider                     NaN    0.272727
# 3C_zh.wikipedia.org_all-access_spider                      NaN   -1.000000
# 4minute_zh.wikipedia.org_all-access_spider                 NaN   -0.628571
# 52_Hz_I_Love_You_zh.wikipedia.org_all-access_sp...         NaN         NaN
#
#                                                     2015-07-03  2015-07-04  \
# Page
# 2NE1_zh.wikipedia.org_all-access_spider              -0.545455         1.6
# 2PM_zh.wikipedia.org_all-access_spider                0.071429         0.2
# 3C_zh.wikipedia.org_all-access_spider                      inf         0.0
# 4minute_zh.wikipedia.org_all-access_spider           -0.230769         8.4
# 52_Hz_I_Love_You_zh.wikipedia.org_all-access_sp...         NaN         NaN
#
# ...

# %%
pct_change.to_csv("../data/pct_changeDF.csv")
